# %%
'''
Process raw NCT00174655 records
to sequence patient records.
'''

# !pip install sas7bdat
from sas7bdat import SAS7BDAT
from collections import defaultdict
import random
import numpy as np
from tqdm import tqdm
random.seed(1234)
np.random.seed(1234)
import dill
import os
os.chdir('./breast cancer/NCT00174655')
# Out:
# Requirement already satisfied: sas7bdat in e:\anaconda3\envs\transtab\lib\site-packages (2.2.3)
# Requirement already satisfied: six>=1.8.0 in e:\anaconda3\envs\transtab\lib\site-packages (from sas7bdat) (1.16.0)

# %%
'''
output patient record
baseline: a table
visit_day: visit days at each admission
visits: a patient record is like
{
    'order':['ae','..','..'] # the order of event types in each visit
    'visit':[
        [[0,1,2,],[0,1,2,3],[1,2,3]],  # first visit
        [[0,2,2],[0,2,3],[1,2,4]], # second visit
    ..],
}
vocab: {'ae': Voc}
'''
# Out:
# "\noutput patient record\nbaseline: a table\nvisit_day: visit days at each admission\nvisits: a patient record is like\n{\n    'order':['ae','..','..'] # the order of event types in each visit\n    'visit':[\n        [[0,1,2,],[0,1,2,3],[1,2,3]],  # first visit\n        [[0,2,2],[0,2,3],[1,2,4]], # second visit\n    ..],\n}\nvocab: {'ae': Voc}\n"

# %%
# structure each patient visit sequence
with SAS7BDAT('vis_date.sas7bdat', skip_header=False) as reader: # all visit information
    df = reader.to_data_frame()
df['ZVISNAME'].unique()
df = df[df['ZVISNAME'].map(lambda x: x not in ['ABBFU1','ABBFU2','SECMALG','ABBFU5','ABBFU6','ABBFU7','ABBFU8'])].reset_index(drop=True)
df['days'] = df[['ZVISD_B_DY','ZVISD_C_DY','ZVISD_F_DY','ZVISD_R_DY','ZVISD_SP_DY']].fillna(0).sum(1)
df_visit = df.copy()[['RUSUBJID','ZVISNAME','days']]
df_groupby = df[['ZVISNAME','days','RUSUBJID']].sort_values(by=['days']).groupby('RUSUBJID')
days_df = df_groupby['days'].agg(list).reset_index()
visit_df = df_groupby['ZVISNAME'].agg(list).reset_index()
visit_df = days_df.merge(visit_df,on='RUSUBJID')
visit_df['days'] = visit_df['days'].apply(lambda x: np.array(x)).apply(lambda x: (x - x[0]).tolist())
visit_df['days'] = visit_df['days'].map(lambda x: x[1:])
visit_df['ZVISNAME'] = visit_df['ZVISNAME'].map(lambda x: x[1:])
visit_df
# Out:
#                RUSUBJID                                               days  \
# 0    000315-000-999-001  [7.0, 28.0, 49.0, 77.0, 105.0, 134.0, 168.0, 2...
# 1    000315-000-999-002  [2.0, 22.0, 42.0, 63.0, 84.0, 112.0, 140.0, 28...
# 2    000315-000-999-003  [12.0, 33.0, 54.0, 75.0, 103.0, 138.0, 173.0, ...
# 3    000315-000-999-004  [6.0, 27.0, 48.0, 69.0, 90.0, 118.0, 146.0, 26...
# 4    000315-000-999-005  [1.0, 21.0, 59.0, 71.0, 80.0, 101.0, 129.0, 15...
# ..                  ...                                                ...
# 987  000315-000-999-990  [18.0, 40.0, 61.0, 82.0, 110.0, 138.0, 166.0, ...
# 988  000315-000-999-991  [7.0, 32.0, 53.0, 74.0, 93.0, 123.0, 151.0, 28...
# 989  000315-000-999-992       [7.0, 35.0, 56.0, 84.0, 112.0, 147.0, 182.0]
# 990  000315-000-999-993  [9.0, 29.0, 50.0, 78.0, 99.0, 134.0, 167.0, 28...
# 991  000315-000-999-994  [13.0, 34.0, 55.0, 76.0, 97.0, 127.0, 162.0, 2...
#
#                                               ZVISNAME
# 0    [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 1    [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 2    [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 3    [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 4    [CHIMIO1, CHIMIO2, CHIMIO3, FOLUP2, CHIMIO4, C...
# ..                                                 ...
# 987  [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 988  [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 989  [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 990  [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 991  [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
#
# [992 rows x 3 columns]

# %%
df_visit = df_visit[~df_visit['ZVISNAME'].isin(['BASELINE'])].reset_index(drop=True)

# %%
# process ae events inside each visit
with SAS7BDAT('ae.sas7bdat', skip_header=False) as reader: # adverse effects
    df = reader.to_data_frame()
df['ZVISNAME'].unique()
# Out:
# array(['CHIMIO1', 'CHIMIO2', 'CHIMIO3', 'CHIMIO4', 'CHIMIO5', 'CHIMIO6',
#        'CHIMIO7', 'FOLUP1', 'FOLUP2', 'FOLUP3', 'FOLUP4', 'BASELINE',
#        'FOLUP5', 'CHIMIO8', 'CHIMIO9', 'FOLUP6', 'FOLUP7', 'FOLUP10',
#        'FOLUP11', 'FOLUP8', 'FOLUP9', 'ABBFU5', 'ABBFU1'], dtype=object)

# %%
# build a map of AECOS and C_AECOS, key: C_AECOS, value: AECOS
aes = df[['AECOS','C_AECOS']]
aes = aes.drop_duplicates()
c_aecos2ae = dict(zip(aes['C_AECOS'],aes['AECOS']))
c_aecos2ae
# Out:
# {'00038': 'ALOPECIA',
#  '00753': 'NAUSEA',
#  '01028': 'STOMATITIS',
#  '00107': 'ARTHRALGIA',
#  '00830': 'PAIN',
#  '01040': 'SYNCOPE',
#  '00997': 'SKIN DIS',
#  '00695': 'LYMPHEDEMA',
#  '00836': 'PAIN CHEST',
#  '00307': 'DIZZINESS',
#  '00447': 'GINGIVITIS',
#  '00301': 'DIARRHEA',
#  '00521': 'HEMATURIA',
#  '00751': 'NAIL DIS',
#  '00487': 'HEADACHE',
#  '00327': 'DYSPNEA',
#  '00114': 'ASTHENIA',
#  '01174': 'WEIGHT INC',
#  '00042': 'AMENORRHEA',
#  '00539': 'HERPES SIMPLEX',
#  '00249': 'CONSTIP',
#  '00795': 'NEUROPATHY',
#  '00718': 'MENS DIS',
#  '00540': 'HERPES ZOSTER',
#  '00619': 'INFECT',
#  '01168': 'VOMIT',
#  '00429': 'FLU SYND',
#  '00831': 'PAIN ABDO',
#  '00824': 'OTITIS MED',
#  '00877': 'PERSON DIS',
#  '00292': 'DEPRESSION',
#  '00428': 'FLATUL',
#  '00513': 'HEM RECTAL',
#  '00654': 'LACRIMATION DIS',
#  '00037': 'ALLERG REACT',
#  '00945': 'RADIAT INJ',
#  '01051': 'TASTE PERVERS',
#  '01153': 'VASODILAT',
#  '00732': 'MONILIA VAGINA',
#  '00958': 'RECTAL DIS',
#  '00879': 'PHARYNGITIS',
#  '00846': 'PALPITAT',
#  '00970': 'RHINITIS',
#  '01055': 'TENOSYNOVITIS',
#  '00084': 'ANOREXIA',
#  '00248': 'CONJUNCTIVITIS',
#  '00722': 'METRORRHAGIA',
#  '00325': 'DYSPEPSIA',
#  '00839': 'PAIN EYE',
#  '': '',
#  '00402': 'EYE DIS',
#  '00278': 'CYSTITIS',
#  '00926': 'PRURITUS',
#  '00919': 'PROCTITIS',
#  '00092': 'ANXIETY',
#  '00410': 'FEVER',
#  '00594': 'HYPOTENS',
#  '00384': 'EPISTAXIS',
#  '01038': 'SWEAT',
#  '00099': 'ARRHYTHMIA',
#  '00560': 'HYPERKALEM',
#  '00624': 'INJECT SITE REACT',
#  '00693': 'LYMPHADENO',
#  '00723': 'MIGRAINE',
#  '00314': 'DRY EYE',
#  '00866': 'PAROSMIA',
#  '00261': 'COUGH INC',
#  '00896': 'PNEUMONIA',
#  '00016': 'ACNE',
#  '00597': 'HYPOTHYR',
#  '00814': 'OPHTHALMITIS',
#  '00906': 'POLYURIA',
#  '00329': 'DYSURIA',
#  '00346': 'EDEMA PERIPH',
#  '00363': 'EMOTION LABIL',
#  '00391': 'ESOPHAGITIS',
#  '00625': 'INJURY ACCID',
#  '00276': 'CYST',
#  '00736': 'MUCOUS MEM DIS',
#  '00440': 'GASTRITIS',
#  '00197': 'CARDIOVASC DIS',
#  '00627': 'INSOMNIA',
#  '01148': 'VAGINITIS',
#  '00300': 'DIABETES MELL',
#  '00622': 'INFECT URIN TRACT',
#  '00209': 'CHILLS',
#  '00001': 'ABDO ENLARGE',
#  '00170': 'BRONCHITIS',
#  '01132': 'URIN FREQUENCY',
#  '00008': 'ABSCESS PERIODONT',
#  '00737': 'MYALGIA',
#  '00496': 'HEM',
#  '00881': 'PHLEB',
#  '01169': 'VULVOVAGINAL DIS',
#  '01050': 'TASTE LOSS',
#  '01173': 'WEIGHT DEC',
#  '00852': 'PANCYTOPENIA',
#  '00330': 'EAR DIS',
#  '00726': 'MONILIA',
#  '01160': 'VERTIGO',
#  '00716': 'MENOPAUSE',
#  '00699': 'MALAISE',
#  '00572': 'HYPERTONIA',
#  '00705': 'MASTITIS',
#  '01167': 'VOICE ALTERAT',
#  '00681': 'LIBIDO DEC',
#  '00946': 'RASH',
#  '00315': 'DRY MOUTH',
#  '00115': 'ASTHMA',
#  '00296': 'DERM FUNG',
#  '00999': 'SKIN DRY',
#  '00767': 'NEOPL',
#  '01086': 'TONGUE DIS',
#  '01001': 'SLEEP DIS',
#  '00373': 'ENTEROCOL',
#  '00444': 'GI DIS',
#  '00680': 'LEUKORRHEA',
#  '01114': 'ULCER PEPTIC',
#  '00279': 'DEAF',
#  '00974': 'SALIVA INC',
#  '00798': 'NOCTURIA',
#  '00799': 'NODULE SKIN',
#  '00788': 'NERVOUSNESS',
#  '00689': 'LIVER FUNC ABNORM',
#  '00489': 'HEALING ABNORM',
#  '00677': 'LEUKOPENIA',
#  '00996': 'SINUSITIS',
#  '00842': 'PAIN NECK',
#  '00559': 'HYPERGLYCEM',
#  '01076': 'THROMBOPHLEB',
#  '00362': 'EMB PULM',
#  '01062': 'THROM',
#  '00835': 'PAIN BREAST',
#  '00004': 'ABSCESS',
#  '01163': 'VISION ABNORM',
#  '00952': 'RASH VESIC BULL',
#  '00957': 'REACT UNEVAL',
#  '00262': 'CRAMPS LEG',
#  '00442': 'GASTROENTERITIS',
#  '00838': 'PAIN EAR',
#  '00729': 'MONILIA ORAL',
#  '00377': 'ENZYME ABNORM',
#  '00208': 'CHEILITIS',
#  '00352': 'EFFUS PLEURAL',
#  '00717': 'MENORRHAGIA',
#  '00287': 'DEHYDRAT',
#  '01087': 'TOOTH CARIES',
#  '00351': 'EFFUS PERICARD',
#  '00771': 'NEOPL BREAST',
#  '00961': 'REFRACT DIS',
#  '00834': 'PAIN BONE',
#  '00048': 'ANEMIA',
#  '00328': 'DYSTONIA',
#  '00568': 'HYPERTENS',
#  '00108': 'ARTHRITIS',
#  '01075': 'THROMBOCYTOPENIA',
#  '00518': 'HEM VAGINAL',
#  '00832': 'PAIN BACK',
#  '00041': 'AMBLYOPIA',
#  '00865': 'PARESTHESIA',
#  '00234': 'COAGUL DIS',
#  '01119': 'ULCER SKIN',
#  '00562': 'HYPERLIPEM',
#  '00195': 'CARDIOMYOPATHY',
#  '00412': 'FIBRILLAT ATR',
#  '00656': 'LACTATION FEM',
#  '00659': 'LARYNGITIS',
#  '00863': 'PARATHYR DIS',
#  '00201': 'CELLULITIS',
#  '00150': 'BLEPHARITIS',
#  '00578': 'HYPESTHESIA',
#  '00298': 'DERMATOMYOSITIS',
#  '01149': 'VASC DIS',
#  '00335': 'ECZEMA',
#  '00998': 'SKIN DISCOLOR',
#  '00043': 'AMNESIA',
#  '00443': 'GGTP INC',
#  '01061': 'THIRST',
#  '00323': 'DYSMENORRHEA',
#  '00238': 'COLITIS',
#  '00250': 'CONVULS',
#  '00199': 'CATARACT NOS',
#  '00340': 'EDEMA GENERAL',
#  '01091': 'TREMOR',
#  '01170': 'VULVOVAGINITIS',
#  '00886': 'PHOTOSENSITIVITY',
#  '00326': 'DYSPHAGIA',
#  '00623': 'INFLAM INJECT SITE',
#  '00026': 'AGITATION',
#  '00339': 'EDEMA FACE',
#  '01082': 'THYROIDITIS',
#  '00336': 'EDEMA',
#  '00985': 'SEPSIS',
#  '00102': 'ARRHYTHMIA VENT',
#  '00557': 'HYPERCHOLESTEREM',
#  '00790': 'NEURITIS',
#  '00002': 'ABDO SYND ACUTE',
#  '01004': 'SPEECH DIS',
#  '00331': 'ECCHYMOSIS',
#  '01155': 'VEIN VARICOSE',
#  '00558': 'HYPERESTHESIA',
#  '01060': 'THINKING ABNORM',
#  '00541': 'HICCUP',
#  '01098': 'ULCER CORNEAL',
#  '00534': 'HEPATOMEGALY',
#  '00111': 'ARTHROSIS',
#  '01046': 'TACHYCARDIA',
#  '00527': 'HEMOPTYSIS',
#  '00214': 'CHOLECYST',
#  '00833': 'PAIN BIL',
#  '01083': 'TINNITUS',
#  '01130': 'URIN ABNORM',
#  '00637': 'ISCHEMIA MYOCARD',
#  '00096': 'APPETITE INC',
#  '01134': 'URIN RETENT',
#  '00203': 'CEREBELL SYND',
#  '00613': 'INCONTIN URIN',
#  '00841': 'PAIN KIDNEY',
#  '00586': 'HYPOKALEM',
#  '00005': 'ABSCESS BREAST',
#  '00567': 'HYPERPLASIA ENDOMETR',
#  '00460': 'GOITER',
#  '00571': 'HYPERTHYR',
#  '00553': 'HYPERCALCEM',
#  '00901': 'PNEUMOTHORAX',
#  '00642': 'KERATITIS',
#  '00648': 'KIDNEY FUNC ABNORM',
#  '00324': 'DYSPAREUNIA',
#  '00504': 'HEM GUM',
#  '00728': 'MONILIA GI',
#  '00503': 'HEM GI',
#  '00338': 'EDEMA CONJUNCT',
#  '00712': 'MELENA',
#  '00587': 'HYPOKINESIA',
#  '01096': 'UG DIS',
#  '00165': 'BREAST ENLARGE',
#  '01088': 'TOOTH DIS',
#  '01077': 'THROMBOPHLEB DEEP',
#  '00519': 'HEMATEMESIS',
#  '01002': 'SOMNOLENCE',
#  '00646': 'KIDNEY FAIL',
#  '00756': 'NECK RIGID',
#  '00601': 'HYPOXIA',
#  '00738': 'MYASTHENIA',
#  '00579': 'HYPOCALCEM',
#  '00095': 'APNEA',
#  '00885': 'PHOTOPHOBIA',
#  '00385': 'ERUCTAT',
#  '00308': 'DREAM ABNORM',
#  '00823': 'OTITIS EXT',
#  '00951': 'RASH PUST',
#  '01135': 'URIN TRACT DIS',
#  '00694': 'LYMPHANGITIS',
#  '00962': 'RESPIRAT DIS',
#  '00820': 'OSTEOPOROSIS',
#  '01011': 'SPUTUM INC',
#  '00151': 'BLIND',
#  '00992': 'SGPT INC',
#  '00576': 'HYPERVENTIL',
#  '00500': 'HEM CYSTITIS',
#  '00574': 'HYPERTROPHY SKIN',
#  '00660': 'LDH INC',
#  '00845': 'PALLOR',
#  '00176': 'BURSITIS',
#  '01136': 'URIN URGENCY',
#  '00422': 'FIBRO LUNG',
#  '00542': 'HIRSUTISM',
#  '00524': 'HEMOLYSIS',
#  '00812': 'OCULOGYRIC CRISIS',
#  '01106': 'ULCER INTEST',
#  '00800': 'NODULE SUBCUTAN',
#  '00483': 'HALITOSIS',
#  '00595': 'HYPOTENS POST',
#  '00546': 'HYDROCEPHALUS',
#  '00641': 'JOINT DIS',
#  '01150': 'VASC DIS PERIPH',
#  '00561': 'HYPERKINESIA',
#  '01138': 'URTICARIA',
#  '00455': 'GLOSSITIS',
#  '00304': 'DIPLOPIA',
#  '00837': 'PAIN CHEST SUBSTERN',
#  '00295': 'DERM EXFOL',
#  '00691': 'LUNG DIS',
#  '00840': 'PAIN INJECT SITE',
#  '01113': 'ULCER MOUTH'}

# %%
df = df.merge(df_visit, on=['ZVISNAME','RUSUBJID'], how='inner')
df = df.sort_values(by=['days'])
df = df[df['C_AECOS'].map(len) > 0].reset_index(drop=True)
# df['AECOS'] # COSTART adverse event coding system
# df['C_AECOS'] # Code of COSTART
df = df[['RUSUBJID','ZVISNAME','C_AECOS','AESER','days']]

df['AESER'] = df['AESER'].replace({'.':0,'No':0,'Yes':1})
df_ae = df.groupby(['RUSUBJID','ZVISNAME'])['C_AECOS'].unique().reset_index()
df['AESER'] = (df['AESER'] * df['C_AECOS']).replace({'':'NO'})
df_ae_ser = df.groupby(['RUSUBJID','ZVISNAME'])['AESER'].unique().reset_index()
df_ae_ser['AESER'] = df_ae_ser['AESER'].apply(lambda x: [x_ for x_ in x.tolist() if x_ != 'NO'] if len(x)>1 and 'NO' in x else x.tolist())
df_ae = df_ae.merge(df_ae_ser, on=['RUSUBJID','ZVISNAME'])
df_ae = df_ae.merge(df_visit, on=['ZVISNAME','RUSUBJID'], how='inner')
df_ae[df_ae['ZVISNAME'] == 'BCR1'] # no AE detected in BCR
df_ae
# Out:
#                 RUSUBJID ZVISNAME  \
# 0     000315-000-999-001  CHIMIO1
# 1     000315-000-999-001  CHIMIO2
# 2     000315-000-999-001  CHIMIO3
# 3     000315-000-999-001  CHIMIO4
# 4     000315-000-999-001  CHIMIO5
# ...                  ...      ...
# 8572  000315-000-999-994  CHIMIO6
# 8573  000315-000-999-994  CHIMIO7
# 8574  000315-000-999-994   FOLUP1
# 8575  000315-000-999-994   FOLUP3
# 8576  000315-000-999-994   FOLUP4
#
#                                                 C_AECOS           AESER   days
# 0            [00038, 00830, 01040, 00753, 01028, 00107]            [NO]    6.0
# 1     [00038, 00753, 00307, 01028, 00836, 00997, 00695]            [NO]   27.0
# 2            [00038, 00753, 00997, 00695, 01028, 00836]            [NO]   48.0
# 3                   [00695, 00447, 00997, 01028, 00038]            [NO]   76.0
# 4                   [01028, 00753, 00301, 00038, 00521]            [NO]  104.0
# ...                                                 ...             ...    ...
# 8572  [00830, 01168, 00114, 00440, 00261, 00627, 011...  [01168, 00753]  120.0
# 8573  [00038, 00753, 00737, 00830, 01153, 00114, 006...            [NO]  155.0
# 8574  [00261, 00114, 00830, 00440, 00038, 01153, 00627]            [NO]  287.0
# 8575                                            [01153]            [NO]  508.0
# 8576                                            [01153]            [NO]  553.0
#
# [8577 rows x 5 columns]

# %%
# with SAS7BDAT('bcrelap.sas7bdat', skip_header=False) as reader:  # 癌症复发
#     df = reader.to_data_frame()

# %%
# medication and dosage for the candidate treatment
with SAS7BDAT('ptxd.sas7bdat', skip_header=False) as reader: 
    df = reader.to_data_frame()
df = df[df['BTXCHOIX'].map(lambda x: x not in ['.'])].reset_index(drop=True)
df = df.sort_values(by=['D_OTXSTR_DY'])
df_groupby = df.groupby(by=['ZVISNAME','RUSUBJID'])
df_ptxd = df_groupby['BTXCHOIX'].unique().reset_index()
df_data = df_ptxd.merge(df_ae, on=['ZVISNAME','RUSUBJID'], how='outer')

# %%
df_data
# Out:
#      ZVISNAME            RUSUBJID                         BTXCHOIX  \
# 0     CHIMIO1  000315-000-999-001  [DOXORUBICIN, CYCLOPHOSPHAMIDE]
# 1     CHIMIO1  000315-000-999-002                    [DOXORUBICIN]
# 2     CHIMIO1  000315-000-999-003                    [DOXORUBICIN]
# 3     CHIMIO1  000315-000-999-004  [DOXORUBICIN, CYCLOPHOSPHAMIDE]
# 4     CHIMIO1  000315-000-999-005  [CYCLOPHOSPHAMIDE, DOXORUBICIN]
# ...       ...                 ...                              ...
# 8662   FOLUP5  000315-000-999-993                              NaN
# 8663   FOLUP6  000315-000-999-993                              NaN
# 8664   FOLUP1  000315-000-999-994                              NaN
# 8665   FOLUP3  000315-000-999-994                              NaN
# 8666   FOLUP4  000315-000-999-994                              NaN
#
#                                                 C_AECOS AESER   days
# 0            [00038, 00830, 01040, 00753, 01028, 00107]  [NO]    6.0
# 1                                               [00038]  [NO]    3.0
# 2                                        [00038, 00249]  [NO]    3.0
# 3                          [00038, 01168, 00429, 00831]  [NO]    5.0
# 4                          [00038, 00753, 00114, 00718]  [NO]    2.0
# ...                                                 ...   ...    ...
# 8662                                            [01153]  [NO]  638.0
# 8663                                            [01153]  [NO]  729.0
# 8664  [00261, 00114, 00830, 00440, 00038, 01153, 00627]  [NO]  287.0
# 8665                                            [01153]  [NO]  508.0
# 8666                                            [01153]  [NO]  553.0
#
# [8667 rows x 6 columns]

# %%
with SAS7BDAT('ptxd.sas7bdat', skip_header=False) as reader: 
    df = reader.to_data_frame()

# %%
# with SAS7BDAT('hospi.sas7bdat', skip_header=False) as reader: # 住院
#     df = reader.to_data_frame()
# df['ADMREAS'].unique() #住院原因
# df[df['ADMREAS'].map(lambda x: x != '.')]['ADMREAS'].value_counts()

# %%
# xray 超声等检查
# with SAS7BDAT('scan.sas7bdat', skip_header=False) as reader: 
#     df = reader.to_data_frame()
# df = df[['RUSUBJID','ZVISNAME','TYPE']]
# df = df[df['TYPE'].map(lambda x: x not in ['Not applicable due to prior Mastectomy','.'])].reset_index(drop=True)
# df_base = df[df['ZVISNAME']=='BASELINE']
# df = df[~df.index.isin(df_base.index)]
# df_groupby = df.groupby(by=['ZVISNAME','RUSUBJID'])
# df_scan = df_groupby['TYPE'].unique().reset_index()
# df_scan = df_scan.merge(df_visit, on=['RUSUBJID','ZVISNAME'], how='inner')
# df_data = df_data.merge(df_scan, how='outer')
# df_data
# df_base = df_base.groupby('RUSUBJID')['TYPE'].unique().reset_index()
# df_base = df_base.rename(columns={'TYPE':'scan_type'})
# df_base['scan_type'].map(len).value_counts()

# %%
# medication and dosage irrelevant to the candidate treatment
with SAS7BDAT('pctx.sas7bdat', skip_header=False) as reader: 
    df = reader.to_data_frame()
df = df.merge(df_visit)

# filter most common 100 med
df = df[df['C_CTXWHO'].map(len) > 1].reset_index(drop=True)
med_count = df.groupby(by=['C_CTXWHO']).size().reset_index().rename(columns={0:'count'}).sort_values(by=['count'], ascending=False).reset_index(drop=True)
df = df[df['C_CTXWHO'].isin(med_count.loc[:99,'C_CTXWHO'])]
df = df[['ZVISNAME','RUSUBJID','C_CTXWHO','days']].sort_values(by=['days'])
df_med = df.groupby(['RUSUBJID','ZVISNAME'])['C_CTXWHO'].unique().reset_index()
df_data = df_data.merge(df_med,how='outer')

# %%
with SAS7BDAT('vital.sas7bdat', skip_header=False) as reader:
    df = reader.to_data_frame()
df['ZVISNAME'].unique()
df_base = df[df['ZVISNAME'] == 'BASELINE']
df_vital = df[~df.index.isin(df_base.index)]
df_base = df_base[['RUSUBJID','PSKAR','HT','WT']].rename(columns={'PSKAR':'performance status', 'HT':'height','WT':'weight'})
df_vital = df_vital.dropna(subset=['PSKAR'])
df_vital = df_vital.merge(df_visit).sort_values(by='days')[['RUSUBJID','days','ZVISNAME','PSKAR']].reset_index(drop=True)

# df_data = df_data.merge(df_vital, on=['RUSUBJID','ZVISNAME','days'], how='left')

# %%
df_data
# Out:
#      ZVISNAME            RUSUBJID                         BTXCHOIX  \
# 0     CHIMIO1  000315-000-999-001  [DOXORUBICIN, CYCLOPHOSPHAMIDE]
# 1     CHIMIO1  000315-000-999-002                    [DOXORUBICIN]
# 2     CHIMIO1  000315-000-999-003                    [DOXORUBICIN]
# 3     CHIMIO1  000315-000-999-004  [DOXORUBICIN, CYCLOPHOSPHAMIDE]
# 4     CHIMIO1  000315-000-999-005  [CYCLOPHOSPHAMIDE, DOXORUBICIN]
# ...       ...                 ...                              ...
# 9091   FOLUP5  000315-000-999-980                              NaN
# 9092   FOLUP1  000315-000-999-983                              NaN
# 9093   FOLUP5  000315-000-999-985                              NaN
# 9094   FOLUP1  000315-000-999-986                              NaN
# 9095   FOLUP5  000315-000-999-986                              NaN
#
#                                          C_AECOS AESER  days  \
# 0     [00038, 00830, 01040, 00753, 01028, 00107]  [NO]   6.0
# 1                                        [00038]  [NO]   3.0
# 2                                 [00038, 00249]  [NO]   3.0
# 3                   [00038, 01168, 00429, 00831]  [NO]   5.0
# 4                   [00038, 00753, 00114, 00718]  [NO]   2.0
# ...                                          ...   ...   ...
# 9091                                         NaN   NaN   NaN
# 9092                                         NaN   NaN   NaN
# 9093                                         NaN   NaN   NaN
# 9094                                         NaN   NaN   NaN
# 9095                                         NaN   NaN   NaN
#
#                                                C_CTXWHO
# 0               [00955301001, 00016001001, 00041902003]
# 1     [00300101002, 00016001001, R0032201003, 002732...
# 2     [00955302R01, R0116901006, 00133002007, 000365...
# 3                            [00661201001, 00955301001]
# 4     [00041902003, 00955302R01, 00016001001, 000365...
# ...                                                 ...
# 9091                                      [00388701001]
# 9092                                      [00388701001]
# 9093                                      [00388701001]
# 9094                                      [00388701001]
# 9095                                      [00388701001]
#
# [9096 rows x 7 columns]

# %%
# 抗癌治疗
# with SAS7BDAT('syscantx.sas7bdat', skip_header=False) as reader:
#     df = reader.to_data_frame()
# df['ZVISNAME'].value_counts()
# df = df[['ZVISNAME','RUSUBJID','C_CTXWHO','ZVISDATE_DY']].rename(columns={'ZVISDATE_DY':'days'})
# df = df[df['C_CTXWHO'].map(len) > 0].reset_index(drop=True)
# df_syscantx = df[df['ZVISNAME'].isin(['BCR1','BCR2'])]
# df_syscantx

# %%
# process death events or labels
with SAS7BDAT('death.sas7bdat', skip_header=False) as reader: # death events
    df = reader.to_data_frame()
df['ZVISNAME'].unique()
df_base = df_base.merge(df[['RUSUBJID','ZVISNAME']], how='outer')
df_base = df_base.rename(columns={'ZVISNAME':'death'})
df_base = df_base.fillna(0)

# %%
with SAS7BDAT('demog.sas7bdat', skip_header=False) as reader: # demographic
    df = reader.to_data_frame()
df = df[['AGE','RACE','SEX','RUSUBJID']]
df_base = df_base.merge(df, on=['RUSUBJID'], how='inner')

# %%
with SAS7BDAT('diag1.sas7bdat', skip_header=False) as reader: # 历史手术
    df = reader.to_data_frame()
print(df['ZVISNAME'].unique())
df_sg = df[['SURGERY','RUSUBJID']].groupby('RUSUBJID')['SURGERY'].unique().reset_index()
df_base = df_base.merge(df_sg, how='outer')
df_bcr = df_visit[df_visit['ZVISNAME'].isin(['BCR1','BCR2'])].reset_index(drop=True)
df_bcr = df_bcr.groupby('RUSUBJID')['ZVISNAME'].unique().reset_index()
df_base = df_base.merge(df_bcr, on=['RUSUBJID'],how='left')
df_base['num relapse']=df_base['ZVISNAME'].fillna('').map(len)
df_base = df_base.drop('ZVISNAME', axis=1)
# Out:
# ['BASELINE']

# %%
with SAS7BDAT('diag2.sas7bdat', skip_header=False) as reader:
    df = reader.to_data_frame()
print(df['ZVISNAME'].unique())
df = df[['RUSUBJID','PATHOT','POSALN','PTSIZE','SITE_L','MULTUYN','HISGRADE','HISTYPE']]
df_1 = df[df['PTSIZE'].notnull()].reset_index(drop=True)[['RUSUBJID','PATHOT','PTSIZE','MULTUYN']]
df_2 = df[df['PTSIZE'].isnull()].reset_index(drop=True)[['RUSUBJID','POSALN','SITE_L','HISGRADE','HISTYPE']]
df_diag = df_1.merge(df_2, how='inner')
df_diag = df_diag.rename(columns={'PATHOT':'primary tumor',
                        'PTSIZE':'tumor size',
                        'MULTUYN':'multifocal tumor',
                        'POSALN':'num positive axillary lymph nodes',
                        'SITE_L':'tumor location',
                        'HISGRADE':'histopathologic grade',
                       'HISTYPE':'histopathologic type',})
df_diag['multifocal tumor'] = df_diag['multifocal tumor'].map(lambda x: 1 if x =='Yes' else 0)
# Out:
# ['BASELINE']

# %%
df_base = df_base.merge(df_diag,on='RUSUBJID',how='left')

# %%
with SAS7BDAT('lab.sas7bdat', skip_header=False) as reader: # lab test results
    df = reader.to_data_frame()

# %%
df['LTEST'].value_counts()
# Out:
# Hemoglobin                18796
# Neutrophils               18796
# Platelets                 18796
# White Blood Cells         18795
# ASAT (SGOT)               12449
# Alkaline Phosphatase      12448
# ALAT (SGPT)               12448
# Total Bilirubin           12447
# Creatinine                 9717
# Creatinine Clearance        997
#                             936
# Lutenising Hormone           63
# Follicle Stim. Hormone       63
# Name: LTEST, dtype: int64

# %%
# with SAS7BDAT('mx.sas7bdat', skip_header=False) as reader: # 疾病史 都在baseline
#     df = reader.to_data_frame()

# %%
# with SAS7BDAT('vd_cycle.sas7bdat', skip_header=False) as reader: 
#     df = reader.to_data_frame()
# df[df['RUSUBJID']=='000315-000-999-011']

# %%
# with SAS7BDAT('end.sas7bdat', skip_header=False) as reader:  # 停止化疗
#     df = reader.to_data_frame()
# # 停止化疗的原因
# df['ENDCHEMO'].value_counts()

# %%
os.chdir('../..')

# %%
visit_df
# Out:
#                RUSUBJID                                               days  \
# 0    000315-000-999-001  [7.0, 28.0, 49.0, 77.0, 105.0, 134.0, 168.0, 2...
# 1    000315-000-999-002  [2.0, 22.0, 42.0, 63.0, 84.0, 112.0, 140.0, 28...
# 2    000315-000-999-003  [12.0, 33.0, 54.0, 75.0, 103.0, 138.0, 173.0, ...
# 3    000315-000-999-004  [6.0, 27.0, 48.0, 69.0, 90.0, 118.0, 146.0, 26...
# 4    000315-000-999-005  [1.0, 21.0, 59.0, 71.0, 80.0, 101.0, 129.0, 15...
# ..                  ...                                                ...
# 987  000315-000-999-990  [18.0, 40.0, 61.0, 82.0, 110.0, 138.0, 166.0, ...
# 988  000315-000-999-991  [7.0, 32.0, 53.0, 74.0, 93.0, 123.0, 151.0, 28...
# 989  000315-000-999-992       [7.0, 35.0, 56.0, 84.0, 112.0, 147.0, 182.0]
# 990  000315-000-999-993  [9.0, 29.0, 50.0, 78.0, 99.0, 134.0, 167.0, 28...
# 991  000315-000-999-994  [13.0, 34.0, 55.0, 76.0, 97.0, 127.0, 162.0, 2...
#
#                                               ZVISNAME
# 0    [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 1    [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 2    [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 3    [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 4    [CHIMIO1, CHIMIO2, CHIMIO3, FOLUP2, CHIMIO4, C...
# ..                                                 ...
# 987  [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 988  [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 989  [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 990  [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 991  [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
#
# [992 rows x 3 columns]

# %%
df_data
# Out:
#      ZVISNAME            RUSUBJID                         BTXCHOIX  \
# 0     CHIMIO1  000315-000-999-001  [DOXORUBICIN, CYCLOPHOSPHAMIDE]
# 1     CHIMIO1  000315-000-999-002                    [DOXORUBICIN]
# 2     CHIMIO1  000315-000-999-003                    [DOXORUBICIN]
# 3     CHIMIO1  000315-000-999-004  [DOXORUBICIN, CYCLOPHOSPHAMIDE]
# 4     CHIMIO1  000315-000-999-005  [CYCLOPHOSPHAMIDE, DOXORUBICIN]
# ...       ...                 ...                              ...
# 9091   FOLUP5  000315-000-999-980                              NaN
# 9092   FOLUP1  000315-000-999-983                              NaN
# 9093   FOLUP5  000315-000-999-985                              NaN
# 9094   FOLUP1  000315-000-999-986                              NaN
# 9095   FOLUP5  000315-000-999-986                              NaN
#
#                                          C_AECOS AESER  days  \
# 0     [00038, 00830, 01040, 00753, 01028, 00107]  [NO]   6.0
# 1                                        [00038]  [NO]   3.0
# 2                                 [00038, 00249]  [NO]   3.0
# 3                   [00038, 01168, 00429, 00831]  [NO]   5.0
# 4                   [00038, 00753, 00114, 00718]  [NO]   2.0
# ...                                          ...   ...   ...
# 9091                                         NaN   NaN   NaN
# 9092                                         NaN   NaN   NaN
# 9093                                         NaN   NaN   NaN
# 9094                                         NaN   NaN   NaN
# 9095                                         NaN   NaN   NaN
#
#                                                C_CTXWHO
# 0               [00955301001, 00016001001, 00041902003]
# 1     [00300101002, 00016001001, R0032201003, 002732...
# 2     [00955302R01, R0116901006, 00133002007, 000365...
# 3                            [00661201001, 00955301001]
# 4     [00041902003, 00955302R01, 00016001001, 000365...
# ...                                                 ...
# 9091                                      [00388701001]
# 9092                                      [00388701001]
# 9093                                      [00388701001]
# 9094                                      [00388701001]
# 9095                                      [00388701001]
#
# [9096 rows x 7 columns]

# %%
df_base['death'] = df_base['death'].apply(lambda x: 0 if x == 0 else 1)

# %%
df_base.to_csv('./NCT00174655/feature.csv',index=False)

def write_txt(x, fileloc):
    with open(fileloc, 'w', encoding='utf-8') as f:
        [f.write(l+'\n') for l in x]
        
binary_features = ['multifocal tumor']
write_txt(binary_features, './NCT00174655/binary_feature.txt')
numerical_features = ['performance status','height','weight','age','tumor size']
write_txt(numerical_features, './NCT00174655/numerical_feature.txt')

# %%
df_base
# Out:
#                RUSUBJID  performance status  height weight  death   AGE  \
# 0    000315-000-999-001               100.0   168.0   56.0      0  66.0
# 1    000315-000-999-002               100.0   149.0   66.0      0  44.0
# 2    000315-000-999-003               100.0   170.0   70.3      0  41.0
# 3    000315-000-999-004               100.0   141.0   81.0      0  61.0
# 4    000315-000-999-005               100.0   154.0   57.9      0  51.0
# ..                  ...                 ...     ...    ...    ...   ...
# 989  000315-000-999-990               100.0   174.0   83.0      0  36.0
# 990  000315-000-999-991               100.0   160.0   60.0      0  49.0
# 991  000315-000-999-992                90.0   159.0   61.0      0  38.0
# 992  000315-000-999-993               100.0   167.0   81.5      0  54.0
# 993  000315-000-999-994                90.0   158.0   54.1      0  48.0
#
#           RACE     SEX                     SURGERY  num relapse  \
# 0    Caucasian  Female    [Lumpectomy, Mastectomy]            0
# 1    Caucasian  Female                [Mastectomy]            0
# 2    Caucasian  Female  [Quadrantectomy/Segmental]            0
# 3    Caucasian  Female                [Mastectomy]            0
# 4    Caucasian  Female  [Quadrantectomy/Segmental]            0
# ..         ...     ...                         ...          ...
# 989  Caucasian  Female  [Quadrantectomy/Segmental]            0
# 990  Caucasian  Female  [Quadrantectomy/Segmental]            0
# 991  Caucasian  Female                [Lumpectomy]            0
# 992  Caucasian  Female                [Lumpectomy]            0
# 993  Caucasian  Female  [Quadrantectomy/Segmental]            0
#
#                                 primary tumor  tumor size  multifocal tumor  \
# 0      Tumor 2cm <> 5cm in greatest dimension         3.4               0.0
# 1    Tumor of <=2cm in its greatest dimension         1.5               1.0
# 2      Tumor 2cm <> 5cm in greatest dimension         2.2               0.0
# 3    Tumor of <=2cm in its greatest dimension         2.0               0.0
# 4      Tumor 2cm <> 5cm in greatest dimension         4.7               0.0
# ..                                        ...         ...               ...
# 989    Tumor 2cm <> 5cm in greatest dimension         2.5               0.0
# 990  Tumor of <=2cm in its greatest dimension         1.6               0.0
# 991  Tumor of <=2cm in its greatest dimension         1.3               0.0
# 992    Tumor 2cm <> 5cm in greatest dimension         2.1               0.0
# 993  Tumor of <=2cm in its greatest dimension         1.8               0.0
#
#      num positive axillary lymph nodes tumor location  \
# 0                                  1.0           Left
# 1                                  1.0          Right
# 2                                  1.0          Right
# 3                                  4.0          Right
# 4                                  4.0           Left
# ..                                 ...            ...
# 989                                1.0          Right
# 990                                6.0          Right
# 991                                2.0          Right
# 992                                1.0          Right
# 993                                3.0          Right
#
#                         histopathologic grade            histopathologic type
# 0    Poorly differentiated / Undifferentiated   Infiltrating ductal carcinoma
# 1                   Moderately differentiated   Infiltrating ductal carcinoma
# 2    Poorly differentiated / Undifferentiated   Infiltrating ductal carcinoma
# 3    Poorly differentiated / Undifferentiated   Infiltrating ductal carcinoma
# 4    Poorly differentiated / Undifferentiated   Infiltrating ductal carcinoma
# ..                                        ...                             ...
# 989  Poorly differentiated / Undifferentiated                           Other
# 990                       Well differentiated  Infiltrating lobular carcinoma
# 991                       Well differentiated   Infiltrating ductal carcinoma
# 992                 Moderately differentiated   Infiltrating ductal carcinoma
# 993  Poorly differentiated / Undifferentiated   Infiltrating ductal carcinoma
#
# [994 rows x 17 columns]

# %%
df_data['RUSUBJID'].nunique()
# Out:
# 977

# %%
# start to process sequence
df_data_key = df_data[['RUSUBJID','ZVISNAME']].drop_duplicates()
df_base_key = df_base[['RUSUBJID']].drop_duplicates()
df_visit_key = df_visit[['RUSUBJID','ZVISNAME']].drop_duplicates()
combined_key = df_visit_key.merge(df_data_key, on=['RUSUBJID','ZVISNAME'], how='inner')
combined_key = combined_key.merge(df_base_key, on=['RUSUBJID'], how='inner')

# %%
df_data = df_data.merge(combined_key, on=['RUSUBJID','ZVISNAME'], how='inner')
df_base = df_base.merge(combined_key['RUSUBJID'].drop_duplicates(), on=['RUSUBJID'], how='inner')
df_visit = df_visit.merge(combined_key, on=['RUSUBJID','ZVISNAME'], how='inner')

# %%
# visit_groupby = df_visit.sort_values(by='days').groupby('RUSUBJID')
# visit_df = visit_groupby['ZVISNAME'].agg(list).reset_index()
# days_df = visit_groupby['days'].agg(list).reset_index()
# visit_df = days_df.merge(visit_df)

# %%
# create vocabulary
class Voc(object):
    def __init__(self):
        self.idx2word = {0:'[PAD]'} # default padding index is 0
        self.word2idx = {'[PAD]':0}
    
    def __len__(self):
        return len(self.idx2word.keys())

    def add_sentence(self, sentence):
        for word in sentence:
            if word not in self.word2idx:
                self.idx2word[len(self.word2idx)] = word
                self.word2idx[word] = len(self.word2idx)

zvis_voc = Voc()
treat_voc = Voc()
ae_voc = Voc()
aeser_voc = Voc()
drug_voc = Voc()
v_stage_voc = Voc()
v_stage_voc.add_sentence(['treatment','followup'])

df_data.fillna('[PAD]', inplace=True)

for index, row in visit_df.iterrows():
    zvis_voc.add_sentence(row['ZVISNAME'])
    
for index, row in df_data.iterrows():
    if not len(row['BTXCHOIX'])==0:
        if isinstance(row['BTXCHOIX'], str):
            treat_voc.add_sentence([row['BTXCHOIX']])
        else:
            treat_voc.add_sentence(row['BTXCHOIX'])

    if not len(row['C_AECOS'])==0:
        if isinstance(row['C_AECOS'], str):
            ae_voc.add_sentence([row['C_AECOS']])
        else:
            ae_voc.add_sentence(row['C_AECOS'])
            
    if not len(row['C_CTXWHO'])==0:
        if isinstance(row['C_CTXWHO'], str):
            drug_voc.add_sentence([row['C_CTXWHO']])
        else:
            drug_voc.add_sentence(row['C_CTXWHO'])
            
    if isinstance(row['AESER'], str):
        aeser_voc.add_sentence([row['AESER']])
    else:
        aeser_voc.add_sentence(row['AESER'])

# %%
# create patient record
import pdb

# visit_df['timestamp'] = visit_df['days'].apply(lambda x: np.array(x)).apply(lambda x: (x - x[0]).tolist())
visit_df['timestamp'] = visit_df['days']
df_data = df_data.rename(columns={'BTXCHOIX':'treatment','C_AECOS':'adverse_event','AESER':'ae_serious','C_CTXWHO':'medication'})
records = []
visit_stages = []
timestamp = []
orders = ['treatment','medication','adverse_event','ae_serious','visit_stage','timestamp']
voc_dict = {
    'treatment':treat_voc,
    'medication': drug_voc,
    'adverse_event':ae_voc,
    'ae_serious':aeser_voc,
    'visit_stage':v_stage_voc,
    'timestamp':None,
}

map_event = lambda x: 0 if 'CHIMIO' in x else 1

subject_id_list = []
for subject_id in tqdm(df_base['RUSUBJID'].unique(), 'creating patient records'):
    subject_id_list.append(subject_id)
    item_df = df_data[df_data['RUSUBJID']==subject_id]
    item_visit = visit_df[visit_df['RUSUBJID']==subject_id]
    visit_stages.append([map_event(v) for v in item_visit['ZVISNAME'].tolist()[0]]) # 0: treatment phase, 1: followup phase    
    timestamp.append(item_visit['timestamp'].tolist()[0])
    patient = []
    for num_visit, (index, row) in enumerate(item_df.iterrows()):
        admission = []
        for order in orders:
            if order == 'visit_stage':
                admission.append(visit_stages[-1][num_visit])
            elif order =='timestamp':
                admission.append(timestamp[-1][num_visit])
            else:
                if isinstance(row[order], str): admission.append([voc_dict[order].word2idx[i] for i in [row[order]]])
                else: admission.append([voc_dict[order].word2idx[i] for i in row[order]]) 
        patient.append(admission)
    records.append(patient)
    

dill.dump(records, open('./NCT00174655/visit.pkl','wb'))
dill.dump(voc_dict, open('./NCT00174655/voc.pkl','wb'))
dill.dump(timestamp, open('./NCT00174655/timestamp.pkl','wb'))
dill.dump(visit_stages, open('./NCT00174655/visit_stage.pkl','wb'))
# Out:
# creating patient records: 100%|██████████| 977/977 [00:01<00:00, 545.74it/s]

# %%
df_base.index = df_base['RUSUBJID']

# %%
df_base.loc[subject_id_list].reset_index(drop=True).to_csv('./NCT00174655/feature.csv',index=False)

# %%
visit_df
# Out:
#                RUSUBJID                                               days  \
# 0    000315-000-999-001  [7.0, 28.0, 49.0, 77.0, 105.0, 134.0, 168.0, 2...
# 1    000315-000-999-002  [2.0, 22.0, 42.0, 63.0, 84.0, 112.0, 140.0, 28...
# 2    000315-000-999-003  [12.0, 33.0, 54.0, 75.0, 103.0, 138.0, 173.0, ...
# 3    000315-000-999-004  [6.0, 27.0, 48.0, 69.0, 90.0, 118.0, 146.0, 26...
# 4    000315-000-999-005  [1.0, 21.0, 59.0, 71.0, 80.0, 101.0, 129.0, 15...
# ..                  ...                                                ...
# 987  000315-000-999-990  [18.0, 40.0, 61.0, 82.0, 110.0, 138.0, 166.0, ...
# 988  000315-000-999-991  [7.0, 32.0, 53.0, 74.0, 93.0, 123.0, 151.0, 28...
# 989  000315-000-999-992       [7.0, 35.0, 56.0, 84.0, 112.0, 147.0, 182.0]
# 990  000315-000-999-993  [9.0, 29.0, 50.0, 78.0, 99.0, 134.0, 167.0, 28...
# 991  000315-000-999-994  [13.0, 34.0, 55.0, 76.0, 97.0, 127.0, 162.0, 2...
#
#                                               ZVISNAME  \
# 0    [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 1    [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 2    [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 3    [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 4    [CHIMIO1, CHIMIO2, CHIMIO3, FOLUP2, CHIMIO4, C...
# ..                                                 ...
# 987  [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 988  [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 989  [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 990  [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
# 991  [CHIMIO1, CHIMIO2, CHIMIO3, CHIMIO4, CHIMIO5, ...
#
#                                              timestamp
# 0    [7.0, 28.0, 49.0, 77.0, 105.0, 134.0, 168.0, 2...
# 1    [2.0, 22.0, 42.0, 63.0, 84.0, 112.0, 140.0, 28...
# 2    [12.0, 33.0, 54.0, 75.0, 103.0, 138.0, 173.0, ...
# 3    [6.0, 27.0, 48.0, 69.0, 90.0, 118.0, 146.0, 26...
# 4    [1.0, 21.0, 59.0, 71.0, 80.0, 101.0, 129.0, 15...
# ..                                                 ...
# 987  [18.0, 40.0, 61.0, 82.0, 110.0, 138.0, 166.0, ...
# 988  [7.0, 32.0, 53.0, 74.0, 93.0, 123.0, 151.0, 28...
# 989       [7.0, 35.0, 56.0, 84.0, 112.0, 147.0, 182.0]
# 990  [9.0, 29.0, 50.0, 78.0, 99.0, 134.0, 167.0, 28...
# 991  [13.0, 34.0, 55.0, 76.0, 97.0, 127.0, 162.0, 2...
#
# [992 rows x 4 columns]

# %%
df_base
# Out:
#                               RUSUBJID  performance status  height weight  \
# RUSUBJID
# 000315-000-999-001  000315-000-999-001               100.0   168.0   56.0
# 000315-000-999-002  000315-000-999-002               100.0   149.0   66.0
# 000315-000-999-003  000315-000-999-003               100.0   170.0   70.3
# 000315-000-999-004  000315-000-999-004               100.0   141.0   81.0
# 000315-000-999-005  000315-000-999-005               100.0   154.0   57.9
# ...                                ...                 ...     ...    ...
# 000315-000-999-990  000315-000-999-990               100.0   174.0   83.0
# 000315-000-999-991  000315-000-999-991               100.0   160.0   60.0
# 000315-000-999-992  000315-000-999-992                90.0   159.0   61.0
# 000315-000-999-993  000315-000-999-993               100.0   167.0   81.5
# 000315-000-999-994  000315-000-999-994                90.0   158.0   54.1
#
#                     death   AGE       RACE     SEX  \
# RUSUBJID
# 000315-000-999-001      0  66.0  Caucasian  Female
# 000315-000-999-002      0  44.0  Caucasian  Female
# 000315-000-999-003      0  41.0  Caucasian  Female
# 000315-000-999-004      0  61.0  Caucasian  Female
# 000315-000-999-005      0  51.0  Caucasian  Female
# ...                   ...   ...        ...     ...
# 000315-000-999-990      0  36.0  Caucasian  Female
# 000315-000-999-991      0  49.0  Caucasian  Female
# 000315-000-999-992      0  38.0  Caucasian  Female
# 000315-000-999-993      0  54.0  Caucasian  Female
# 000315-000-999-994      0  48.0  Caucasian  Female
#
#                                        SURGERY  num relapse  \
# RUSUBJID
# 000315-000-999-001    [Lumpectomy, Mastectomy]            0
# 000315-000-999-002                [Mastectomy]            0
# 000315-000-999-003  [Quadrantectomy/Segmental]            0
# 000315-000-999-004                [Mastectomy]            0
# 000315-000-999-005  [Quadrantectomy/Segmental]            0
# ...                                        ...          ...
# 000315-000-999-990  [Quadrantectomy/Segmental]            0
# 000315-000-999-991  [Quadrantectomy/Segmental]            0
# 000315-000-999-992                [Lumpectomy]            0
# 000315-000-999-993                [Lumpectomy]            0
# 000315-000-999-994  [Quadrantectomy/Segmental]            0
#
#                                                primary tumor  tumor size  \
# RUSUBJID
# 000315-000-999-001    Tumor 2cm <> 5cm in greatest dimension         3.4
# 000315-000-999-002  Tumor of <=2cm in its greatest dimension         1.5
# 000315-000-999-003    Tumor 2cm <> 5cm in greatest dimension         2.2
# 000315-000-999-004  Tumor of <=2cm in its greatest dimension         2.0
# 000315-000-999-005    Tumor 2cm <> 5cm in greatest dimension         4.7
# ...                                                      ...         ...
# 000315-000-999-990    Tumor 2cm <> 5cm in greatest dimension         2.5
# 000315-000-999-991  Tumor of <=2cm in its greatest dimension         1.6
# 000315-000-999-992  Tumor of <=2cm in its greatest dimension         1.3
# 000315-000-999-993    Tumor 2cm <> 5cm in greatest dimension         2.1
# 000315-000-999-994  Tumor of <=2cm in its greatest dimension         1.8
#
#                     multifocal tumor  num positive axillary lymph nodes  \
# RUSUBJID
# 000315-000-999-001               0.0                                1.0
# 000315-000-999-002               1.0                                1.0
# 000315-000-999-003               0.0                                1.0
# 000315-000-999-004               0.0                                4.0
# 000315-000-999-005               0.0                                4.0
# ...                              ...                                ...
# 000315-000-999-990               0.0                                1.0
# 000315-000-999-991               0.0                                6.0
# 000315-000-999-992               0.0                                2.0
# 000315-000-999-993               0.0                                1.0
# 000315-000-999-994               0.0                                3.0
#
#                    tumor location                     histopathologic grade  \
# RUSUBJID
# 000315-000-999-001           Left  Poorly differentiated / Undifferentiated
# 000315-000-999-002          Right                 Moderately differentiated
# 000315-000-999-003          Right  Poorly differentiated / Undifferentiated
# 000315-000-999-004          Right  Poorly differentiated / Undifferentiated
# 000315-000-999-005           Left  Poorly differentiated / Undifferentiated
# ...                           ...                                       ...
# 000315-000-999-990          Right  Poorly differentiated / Undifferentiated
# 000315-000-999-991          Right                       Well differentiated
# 000315-000-999-992          Right                       Well differentiated
# 000315-000-999-993          Right                 Moderately differentiated
# 000315-000-999-994          Right  Poorly differentiated / Undifferentiated
#
#                               histopathologic type
# RUSUBJID
# 000315-000-999-001   Infiltrating ductal carcinoma
# 000315-000-999-002   Infiltrating ductal carcinoma
# 000315-000-999-003   Infiltrating ductal carcinoma
# 000315-000-999-004   Infiltrating ductal carcinoma
# 000315-000-999-005   Infiltrating ductal carcinoma
# ...                                            ...
# 000315-000-999-990                           Other
# 000315-000-999-991  Infiltrating lobular carcinoma
# 000315-000-999-992   Infiltrating ductal carcinoma
# 000315-000-999-993   Infiltrating ductal carcinoma
# 000315-000-999-994   Infiltrating ductal carcinoma
#
# [977 rows x 17 columns]

# %%
df_data['RUSUBJID'].nunique()
# Out:
# 977

# %%
orders
# Out:
# ['treatment',
#  'medication',
#  'adverse_event',
#  'ae_serious',
#  'visit_stage',
#  'timestamp']

# %%
df_data[~df_data['ae_serious'].isin(['[PAD]',['NO']])].sort_values(by='RUSUBJID')
# Out:
#      ZVISNAME            RUSUBJID  \
# 4802  CHIMIO6  000315-000-999-032
# 41    CHIMIO1  000315-000-999-043
# 1010  CHIMIO2  000315-000-999-043
# 1976  CHIMIO3  000315-000-999-043
# 2930  CHIMIO4  000315-000-999-043
# ...       ...                 ...
# 5672  CHIMIO6  000315-000-999-965
# 6584  CHIMIO7  000315-000-999-966
# 8600   FOLUP1  000315-000-999-968
# 1922  CHIMIO2  000315-000-999-981
# 5700  CHIMIO6  000315-000-999-994
#
#                                            treatment  \
# 4802  [CYCLOPHOSPHAMIDE, METHOTREXATE, FLUOROURACIL]
# 41                   [CYCLOPHOSPHAMIDE, DOXORUBICIN]
# 1010                 [DOXORUBICIN, CYCLOPHOSPHAMIDE]
# 1976                 [CYCLOPHOSPHAMIDE, DOXORUBICIN]
# 2930                 [CYCLOPHOSPHAMIDE, DOXORUBICIN]
# ...                                              ...
# 5672  [METHOTREXATE, FLUOROURACIL, CYCLOPHOSPHAMIDE]
# 6584  [CYCLOPHOSPHAMIDE, FLUOROURACIL, METHOTREXATE]
# 8600                                           [PAD]
# 1922                                   [DOXORUBICIN]
# 5700  [CYCLOPHOSPHAMIDE, FLUOROURACIL, METHOTREXATE]
#
#                                           adverse_event  \
# 4802         [00753, 00114, 00619, 00209, 00038, 00307]
# 41                         [00114, 01168, 00753, 00038]
# 1010  [00038, 01168, 00114, 00622, 01173, 00831, 00753]
# 1976  [00753, 00038, 00622, 00830, 00114, 00795, 011...
# 2930         [00038, 00753, 01168, 00114, 00622, 01173]
# ...                                                 ...
# 5672                [00038, 00751, 00830, 00622, 00084]
# 6584  [00362, 00327, 00107, 00737, 00114, 00751, 007...
# 8600                                     [00997, 00718]
# 1922  [01168, 00114, 00737, 00830, 00896, 00732, 009...
# 5700  [00830, 01168, 00114, 00440, 00261, 00627, 011...
#
#                  ae_serious   days  \
# 4802                [00619]  121.0
# 41    [00114, 01168, 00753]    3.0
# 1010         [01168, 00753]   27.0
# 1976                [00114]   49.0
# 2930                [01168]   70.0
# ...                     ...    ...
# 5672         [00830, 00622]  119.0
# 6584         [00362, 00327]  159.0
# 8600                [00997]  249.0
# 1922                [00896]   26.0
# 5700         [01168, 00753]  120.0
#
#                                              medication
# 4802  [00041901001, 00020001003, 00116401003, R00229...
# 41    [00041901002, 00008502003, 00614601003, R00322...
# 1010  [00661201RI0, 00614601003, R0032201002, 000085...
# 1976  [R0026301003, 00041901002, 00614601003, 000085...
# 2930  [00041901002, 00614601003, 00697201002, 006612...
# ...                                                 ...
# 5672            [00300101001, 00016201003, 00955301001]
# 6584  [00041901001, 00955301001, 00016001001, R00263...
# 8600                                      [00388701001]
# 1922  [00016001001, 00139501002, 00239101001, 000149...
# 5700  [00163401002, 00595201002, 00661201002, 000365...
#
# [169 rows x 7 columns]

# %%
len(voc_dict['ae_serious'])
# Out:
# 77

# %%
voc_dict['ae_serious'].idx2word
# Out:
# {0: '[PAD]',
#  1: 'NO',
#  2: '00114',
#  3: '01168',
#  4: '00753',
#  5: '00287',
#  6: '00996',
#  7: '00619',
#  8: '00705',
#  9: '00362',
#  10: '01091',
#  11: '00830',
#  12: '00879',
#  13: '00901',
#  14: '00677',
#  15: '00736',
#  16: '00997',
#  17: '01062',
#  18: '01028',
#  19: '00410',
#  20: '00099',
#  21: '00958',
#  22: '00170',
#  23: '00896',
#  24: '00325',
#  25: '00624',
#  26: '00622',
#  27: '00329',
#  28: '01132',
#  29: '00249',
#  30: '00699',
#  31: '00539',
#  32: '00442',
#  33: '00301',
#  34: '00107',
#  35: '00496',
#  36: '00625',
#  37: '00985',
#  38: '00327',
#  39: '00637',
#  40: '00201',
#  41: '01076',
#  42: '00877',
#  43: '00852',
#  44: '00689',
#  45: '00004',
#  46: '00048',
#  47: '00002',
#  48: '00540',
#  49: '00513',
#  50: '00292',
#  51: '00594',
#  52: '00832',
#  53: '00095',
#  54: '00646',
#  55: '00579',
#  56: '00586',
#  57: '00576',
#  58: '00524',
#  59: '00521',
#  60: '00373',
#  61: '00836',
#  62: '00234',
#  63: '00824',
#  64: '00037',
#  65: '00197',
#  66: '00307',
#  67: '01077',
#  68: '00500',
#  69: '00195',
#  70: '00412',
#  71: '00250',
#  72: '00043',
#  73: '00831',
#  74: '00597',
#  75: '00351',
#  76: '00384'}

# %%
c_aecos2ae
# Out:
# {'00038': 'ALOPECIA',
#  '00753': 'NAUSEA',
#  '01028': 'STOMATITIS',
#  '00107': 'ARTHRALGIA',
#  '00830': 'PAIN',
#  '01040': 'SYNCOPE',
#  '00997': 'SKIN DIS',
#  '00695': 'LYMPHEDEMA',
#  '00836': 'PAIN CHEST',
#  '00307': 'DIZZINESS',
#  '00447': 'GINGIVITIS',
#  '00301': 'DIARRHEA',
#  '00521': 'HEMATURIA',
#  '00751': 'NAIL DIS',
#  '00487': 'HEADACHE',
#  '00327': 'DYSPNEA',
#  '00114': 'ASTHENIA',
#  '01174': 'WEIGHT INC',
#  '00042': 'AMENORRHEA',
#  '00539': 'HERPES SIMPLEX',
#  '00249': 'CONSTIP',
#  '00795': 'NEUROPATHY',
#  '00718': 'MENS DIS',
#  '00540': 'HERPES ZOSTER',
#  '00619': 'INFECT',
#  '01168': 'VOMIT',
#  '00429': 'FLU SYND',
#  '00831': 'PAIN ABDO',
#  '00824': 'OTITIS MED',
#  '00877': 'PERSON DIS',
#  '00292': 'DEPRESSION',
#  '00428': 'FLATUL',
#  '00513': 'HEM RECTAL',
#  '00654': 'LACRIMATION DIS',
#  '00037': 'ALLERG REACT',
#  '00945': 'RADIAT INJ',
#  '01051': 'TASTE PERVERS',
#  '01153': 'VASODILAT',
#  '00732': 'MONILIA VAGINA',
#  '00958': 'RECTAL DIS',
#  '00879': 'PHARYNGITIS',
#  '00846': 'PALPITAT',
#  '00970': 'RHINITIS',
#  '01055': 'TENOSYNOVITIS',
#  '00084': 'ANOREXIA',
#  '00248': 'CONJUNCTIVITIS',
#  '00722': 'METRORRHAGIA',
#  '00325': 'DYSPEPSIA',
#  '00839': 'PAIN EYE',
#  '': '',
#  '00402': 'EYE DIS',
#  '00278': 'CYSTITIS',
#  '00926': 'PRURITUS',
#  '00919': 'PROCTITIS',
#  '00092': 'ANXIETY',
#  '00410': 'FEVER',
#  '00594': 'HYPOTENS',
#  '00384': 'EPISTAXIS',
#  '01038': 'SWEAT',
#  '00099': 'ARRHYTHMIA',
#  '00560': 'HYPERKALEM',
#  '00624': 'INJECT SITE REACT',
#  '00693': 'LYMPHADENO',
#  '00723': 'MIGRAINE',
#  '00314': 'DRY EYE',
#  '00866': 'PAROSMIA',
#  '00261': 'COUGH INC',
#  '00896': 'PNEUMONIA',
#  '00016': 'ACNE',
#  '00597': 'HYPOTHYR',
#  '00814': 'OPHTHALMITIS',
#  '00906': 'POLYURIA',
#  '00329': 'DYSURIA',
#  '00346': 'EDEMA PERIPH',
#  '00363': 'EMOTION LABIL',
#  '00391': 'ESOPHAGITIS',
#  '00625': 'INJURY ACCID',
#  '00276': 'CYST',
#  '00736': 'MUCOUS MEM DIS',
#  '00440': 'GASTRITIS',
#  '00197': 'CARDIOVASC DIS',
#  '00627': 'INSOMNIA',
#  '01148': 'VAGINITIS',
#  '00300': 'DIABETES MELL',
#  '00622': 'INFECT URIN TRACT',
#  '00209': 'CHILLS',
#  '00001': 'ABDO ENLARGE',
#  '00170': 'BRONCHITIS',
#  '01132': 'URIN FREQUENCY',
#  '00008': 'ABSCESS PERIODONT',
#  '00737': 'MYALGIA',
#  '00496': 'HEM',
#  '00881': 'PHLEB',
#  '01169': 'VULVOVAGINAL DIS',
#  '01050': 'TASTE LOSS',
#  '01173': 'WEIGHT DEC',
#  '00852': 'PANCYTOPENIA',
#  '00330': 'EAR DIS',
#  '00726': 'MONILIA',
#  '01160': 'VERTIGO',
#  '00716': 'MENOPAUSE',
#  '00699': 'MALAISE',
#  '00572': 'HYPERTONIA',
#  '00705': 'MASTITIS',
#  '01167': 'VOICE ALTERAT',
#  '00681': 'LIBIDO DEC',
#  '00946': 'RASH',
#  '00315': 'DRY MOUTH',
#  '00115': 'ASTHMA',
#  '00296': 'DERM FUNG',
#  '00999': 'SKIN DRY',
#  '00767': 'NEOPL',
#  '01086': 'TONGUE DIS',
#  '01001': 'SLEEP DIS',
#  '00373': 'ENTEROCOL',
#  '00444': 'GI DIS',
#  '00680': 'LEUKORRHEA',
#  '01114': 'ULCER PEPTIC',
#  '00279': 'DEAF',
#  '00974': 'SALIVA INC',
#  '00798': 'NOCTURIA',
#  '00799': 'NODULE SKIN',
#  '00788': 'NERVOUSNESS',
#  '00689': 'LIVER FUNC ABNORM',
#  '00489': 'HEALING ABNORM',
#  '00677': 'LEUKOPENIA',
#  '00996': 'SINUSITIS',
#  '00842': 'PAIN NECK',
#  '00559': 'HYPERGLYCEM',
#  '01076': 'THROMBOPHLEB',
#  '00362': 'EMB PULM',
#  '01062': 'THROM',
#  '00835': 'PAIN BREAST',
#  '00004': 'ABSCESS',
#  '01163': 'VISION ABNORM',
#  '00952': 'RASH VESIC BULL',
#  '00957': 'REACT UNEVAL',
#  '00262': 'CRAMPS LEG',
#  '00442': 'GASTROENTERITIS',
#  '00838': 'PAIN EAR',
#  '00729': 'MONILIA ORAL',
#  '00377': 'ENZYME ABNORM',
#  '00208': 'CHEILITIS',
#  '00352': 'EFFUS PLEURAL',
#  '00717': 'MENORRHAGIA',
#  '00287': 'DEHYDRAT',
#  '01087': 'TOOTH CARIES',
#  '00351': 'EFFUS PERICARD',
#  '00771': 'NEOPL BREAST',
#  '00961': 'REFRACT DIS',
#  '00834': 'PAIN BONE',
#  '00048': 'ANEMIA',
#  '00328': 'DYSTONIA',
#  '00568': 'HYPERTENS',
#  '00108': 'ARTHRITIS',
#  '01075': 'THROMBOCYTOPENIA',
#  '00518': 'HEM VAGINAL',
#  '00832': 'PAIN BACK',
#  '00041': 'AMBLYOPIA',
#  '00865': 'PARESTHESIA',
#  '00234': 'COAGUL DIS',
#  '01119': 'ULCER SKIN',
#  '00562': 'HYPERLIPEM',
#  '00195': 'CARDIOMYOPATHY',
#  '00412': 'FIBRILLAT ATR',
#  '00656': 'LACTATION FEM',
#  '00659': 'LARYNGITIS',
#  '00863': 'PARATHYR DIS',
#  '00201': 'CELLULITIS',
#  '00150': 'BLEPHARITIS',
#  '00578': 'HYPESTHESIA',
#  '00298': 'DERMATOMYOSITIS',
#  '01149': 'VASC DIS',
#  '00335': 'ECZEMA',
#  '00998': 'SKIN DISCOLOR',
#  '00043': 'AMNESIA',
#  '00443': 'GGTP INC',
#  '01061': 'THIRST',
#  '00323': 'DYSMENORRHEA',
#  '00238': 'COLITIS',
#  '00250': 'CONVULS',
#  '00199': 'CATARACT NOS',
#  '00340': 'EDEMA GENERAL',
#  '01091': 'TREMOR',
#  '01170': 'VULVOVAGINITIS',
#  '00886': 'PHOTOSENSITIVITY',
#  '00326': 'DYSPHAGIA',
#  '00623': 'INFLAM INJECT SITE',
#  '00026': 'AGITATION',
#  '00339': 'EDEMA FACE',
#  '01082': 'THYROIDITIS',
#  '00336': 'EDEMA',
#  '00985': 'SEPSIS',
#  '00102': 'ARRHYTHMIA VENT',
#  '00557': 'HYPERCHOLESTEREM',
#  '00790': 'NEURITIS',
#  '00002': 'ABDO SYND ACUTE',
#  '01004': 'SPEECH DIS',
#  '00331': 'ECCHYMOSIS',
#  '01155': 'VEIN VARICOSE',
#  '00558': 'HYPERESTHESIA',
#  '01060': 'THINKING ABNORM',
#  '00541': 'HICCUP',
#  '01098': 'ULCER CORNEAL',
#  '00534': 'HEPATOMEGALY',
#  '00111': 'ARTHROSIS',
#  '01046': 'TACHYCARDIA',
#  '00527': 'HEMOPTYSIS',
#  '00214': 'CHOLECYST',
#  '00833': 'PAIN BIL',
#  '01083': 'TINNITUS',
#  '01130': 'URIN ABNORM',
#  '00637': 'ISCHEMIA MYOCARD',
#  '00096': 'APPETITE INC',
#  '01134': 'URIN RETENT',
#  '00203': 'CEREBELL SYND',
#  '00613': 'INCONTIN URIN',
#  '00841': 'PAIN KIDNEY',
#  '00586': 'HYPOKALEM',
#  '00005': 'ABSCESS BREAST',
#  '00567': 'HYPERPLASIA ENDOMETR',
#  '00460': 'GOITER',
#  '00571': 'HYPERTHYR',
#  '00553': 'HYPERCALCEM',
#  '00901': 'PNEUMOTHORAX',
#  '00642': 'KERATITIS',
#  '00648': 'KIDNEY FUNC ABNORM',
#  '00324': 'DYSPAREUNIA',
#  '00504': 'HEM GUM',
#  '00728': 'MONILIA GI',
#  '00503': 'HEM GI',
#  '00338': 'EDEMA CONJUNCT',
#  '00712': 'MELENA',
#  '00587': 'HYPOKINESIA',
#  '01096': 'UG DIS',
#  '00165': 'BREAST ENLARGE',
#  '01088': 'TOOTH DIS',
#  '01077': 'THROMBOPHLEB DEEP',
#  '00519': 'HEMATEMESIS',
#  '01002': 'SOMNOLENCE',
#  '00646': 'KIDNEY FAIL',
#  '00756': 'NECK RIGID',
#  '00601': 'HYPOXIA',
#  '00738': 'MYASTHENIA',
#  '00579': 'HYPOCALCEM',
#  '00095': 'APNEA',
#  '00885': 'PHOTOPHOBIA',
#  '00385': 'ERUCTAT',
#  '00308': 'DREAM ABNORM',
#  '00823': 'OTITIS EXT',
#  '00951': 'RASH PUST',
#  '01135': 'URIN TRACT DIS',
#  '00694': 'LYMPHANGITIS',
#  '00962': 'RESPIRAT DIS',
#  '00820': 'OSTEOPOROSIS',
#  '01011': 'SPUTUM INC',
#  '00151': 'BLIND',
#  '00992': 'SGPT INC',
#  '00576': 'HYPERVENTIL',
#  '00500': 'HEM CYSTITIS',
#  '00574': 'HYPERTROPHY SKIN',
#  '00660': 'LDH INC',
#  '00845': 'PALLOR',
#  '00176': 'BURSITIS',
#  '01136': 'URIN URGENCY',
#  '00422': 'FIBRO LUNG',
#  '00542': 'HIRSUTISM',
#  '00524': 'HEMOLYSIS',
#  '00812': 'OCULOGYRIC CRISIS',
#  '01106': 'ULCER INTEST',
#  '00800': 'NODULE SUBCUTAN',
#  '00483': 'HALITOSIS',
#  '00595': 'HYPOTENS POST',
#  '00546': 'HYDROCEPHALUS',
#  '00641': 'JOINT DIS',
#  '01150': 'VASC DIS PERIPH',
#  '00561': 'HYPERKINESIA',
#  '01138': 'URTICARIA',
#  '00455': 'GLOSSITIS',
#  '00304': 'DIPLOPIA',
#  '00837': 'PAIN CHEST SUBSTERN',
#  '00295': 'DERM EXFOL',
#  '00691': 'LUNG DIS',
#  '00840': 'PAIN INJECT SITE',
#  '01113': 'ULCER MOUTH'}

# %%
aeidx2aename = {}
for k,v in voc_dict['ae_serious'].idx2word.items():
    aeidx2aename[k] = c_aecos2ae.get(v, v)

# %%
aeidx2aename
# Out:
# {0: '[PAD]',
#  1: 'NO',
#  2: 'ASTHENIA',
#  3: 'VOMIT',
#  4: 'NAUSEA',
#  5: 'DEHYDRAT',
#  6: 'SINUSITIS',
#  7: 'INFECT',
#  8: 'MASTITIS',
#  9: 'EMB PULM',
#  10: 'TREMOR',
#  11: 'PAIN',
#  12: 'PHARYNGITIS',
#  13: 'PNEUMOTHORAX',
#  14: 'LEUKOPENIA',
#  15: 'MUCOUS MEM DIS',
#  16: 'SKIN DIS',
#  17: 'THROM',
#  18: 'STOMATITIS',
#  19: 'FEVER',
#  20: 'ARRHYTHMIA',
#  21: 'RECTAL DIS',
#  22: 'BRONCHITIS',
#  23: 'PNEUMONIA',
#  24: 'DYSPEPSIA',
#  25: 'INJECT SITE REACT',
#  26: 'INFECT URIN TRACT',
#  27: 'DYSURIA',
#  28: 'URIN FREQUENCY',
#  29: 'CONSTIP',
#  30: 'MALAISE',
#  31: 'HERPES SIMPLEX',
#  32: 'GASTROENTERITIS',
#  33: 'DIARRHEA',
#  34: 'ARTHRALGIA',
#  35: 'HEM',
#  36: 'INJURY ACCID',
#  37: 'SEPSIS',
#  38: 'DYSPNEA',
#  39: 'ISCHEMIA MYOCARD',
#  40: 'CELLULITIS',
#  41: 'THROMBOPHLEB',
#  42: 'PERSON DIS',
#  43: 'PANCYTOPENIA',
#  44: 'LIVER FUNC ABNORM',
#  45: 'ABSCESS',
#  46: 'ANEMIA',
#  47: 'ABDO SYND ACUTE',
#  48: 'HERPES ZOSTER',
#  49: 'HEM RECTAL',
#  50: 'DEPRESSION',
#  51: 'HYPOTENS',
#  52: 'PAIN BACK',
#  53: 'APNEA',
#  54: 'KIDNEY FAIL',
#  55: 'HYPOCALCEM',
#  56: 'HYPOKALEM',
#  57: 'HYPERVENTIL',
#  58: 'HEMOLYSIS',
#  59: 'HEMATURIA',
#  60: 'ENTEROCOL',
#  61: 'PAIN CHEST',
#  62: 'COAGUL DIS',
#  63: 'OTITIS MED',
#  64: 'ALLERG REACT',
#  65: 'CARDIOVASC DIS',
#  66: 'DIZZINESS',
#  67: 'THROMBOPHLEB DEEP',
#  68: 'HEM CYSTITIS',
#  69: 'CARDIOMYOPATHY',
#  70: 'FIBRILLAT ATR',
#  71: 'CONVULS',
#  72: 'AMNESIA',
#  73: 'PAIN ABDO',
#  74: 'HYPOTHYR',
#  75: 'EFFUS PERICARD',
#  76: 'EPISTAXIS'}

# %%
import json
json.dump(aeidx2aename, open('./NCT00174655/aeidx2aename.json','w'))
